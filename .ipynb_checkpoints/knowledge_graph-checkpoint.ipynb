# %% [markdown]
# consider this depreciated for the final version. I'm too scared to take it out in case something breaks. visualizations in data/vis folder

# %%
import networkx as nx
from pymongo import MongoClient

# Connect to DB
db = MongoClient("mongodb://mongo:27017").erica

# Load nodes and edges
nodes = list(db.entity_nodes.find({}))
edges = list(db.entity_edges.find({}))

print("Nodes loaded:", len(nodes))
print("Edges loaded:", len(edges))

# Build graph
G = nx.DiGraph()

for n in nodes:
    node_id = n["id"]
    node_type = n["type"]
    label = n.get("title") or n.get("description") or n.get("text") or ""

    G.add_node(node_id,
               type=node_type,
               label=label)

for e in edges:
    G.add_edge(e["source"], e["target"], type=e["type"])

print("Graph built!")
print("Graph nodes:", G.number_of_nodes())
print("Graph edges:", G.number_of_edges())
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[33], line 8
#       5 db = MongoClient("mongodb://mongo:27017").erica
#       7 # Load nodes and edges
# ----> 8 nodes = list(db.entity_nodes.find({}))
#       9 edges = list(db.entity_edges.find({}))
#      11 print("Nodes loaded:", len(nodes))
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/cursor.py:1289, in Cursor.__next__(self)
#    1288 def __next__(self) -> _DocumentType:
# -> 1289     return self.next()
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/cursor.py:1265, in Cursor.next(self)
#    1263 if self._empty:
#    1264     raise StopIteration
# -> 1265 if len(self._data) or self._refresh():
#    1266     return self._data.popleft()
#    1267 else:
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/cursor.py:1213, in Cursor._refresh(self)
#    1191         raise InvalidOperation(
#    1192             "Passing a 'hint' is required when using the min/max query"
#    1193             " option to ensure the query utilizes the correct index"
#    1194         )
#    1195     q = self._query_class(
#    1196         self._query_flags,
#    1197         self._collection.database.name,
#    (...)
#    1211         self._exhaust,
#    1212     )
# -> 1213     self._send_message(q)
#    1214 elif self._id:  # Get More
#    1215     if self._limit:
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/cursor.py:1108, in Cursor._send_message(self, operation)
#    1105     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1107 try:
# -> 1108     response = client._run_operation(
#    1109         operation, self._unpack_response, address=self._address
#    1110     )
#    1111 except OperationFailure as exc:
#    1112     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1113         # Don't send killCursors because the cursor is already closed.
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1938, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1928     operation.reset()  # Reset op in case of retry.
#    1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    (...)
#    1935         self,
#    1936     )
# -> 1938 return self._retryable_read(
#    1939     _cmd,
#    1940     operation.read_preference,
#    1941     operation.session,  # type: ignore[arg-type]
#    1942     address=address,
#    1943     retryable=isinstance(operation, _Query),
#    1944     operation=operation.name,
#    1945 )
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2910, in _ClientConnectionRetryable._read(self)
#    2905 def _read(self) -> T:
#    2906     """Wrapper method for read-type retryable client executions
#    2907
#    2908     :return: Output for func()'s call
#    2909     """
# -> 2910     self._server = self._get_server()
#    2911     assert self._read_pref is not None, "Read Preference required on read calls"
#    2912     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2913         conn,
#    2914         read_pref,
#    2915     ):
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2858, in _ClientConnectionRetryable._get_server(self)
#    2853 def _get_server(self) -> Server:
#    2854     """Retrieves a server object based on provided object context
#    2855
#    2856     :return: Abstraction to connect to server
#    2857     """
# -> 2858     return self._client._select_server(
#    2859         self._server_selector,
#    2860         self._session,
#    2861         self._operation,
#    2862         address=self._address,
#    2863         deprioritized_servers=self._deprioritized_servers,
#    2864         operation_id=self._operation_id,
#    2865     )
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/topology.py:409, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     399 def select_server(
#     400     self,
#     401     selector: Callable[[Selection], Selection],
#    (...)
#     406     operation_id: Optional[int] = None,
#     407 ) -> Server:
#     408     """Like select_servers, but choose a random server if several match."""
# --> 409     server = self._select_server(
#     410         selector,
#     411         operation,
#     412         server_selection_timeout,
#     413         address,
#     414         deprioritized_servers,
#     415         operation_id=operation_id,
#     416     )
#     417     if _csot.get_timeout():
#     418         _csot.set_rtt(server.description.min_round_trip_time)
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/topology.py:387, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     378 def _select_server(
#     379     self,
#     380     selector: Callable[[Selection], Selection],
#    (...)
#     385     operation_id: Optional[int] = None,
#     386 ) -> Server:
# --> 387     servers = self.select_servers(
#     388         selector, operation, server_selection_timeout, address, operation_id
#     389     )
#     390     servers = _filter_servers(servers, deprioritized_servers)
#     391     if len(servers) == 1:
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/topology.py:294, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     291     self.cleanup_monitors()
#     293 with self._lock:
# --> 294     server_descriptions = self._select_servers_loop(
#     295         selector, server_timeout, operation, operation_id, address
#     296     )
#     298     return [
#     299         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     300     ]
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/pymongo/synchronous/topology.py:344, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     333     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     334         _debug_log(
#     335             _SERVER_SELECTION_LOGGER,
#     336             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     342             failure=self._error_message(selector),
#     343         )
# --> 344     raise ServerSelectionTimeoutError(
#     345         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     346     )
#     348 if not logged_waiting:
#     349     _debug_log(
#     350         _SERVER_SELECTION_LOGGER,
#     351         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     357         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     358     )
#
# ServerSelectionTimeoutError: mongo:27017: [Errno 8] nodename nor servname provided, or not known (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6934abe7e3d93dca42535a31, topology_type: Unknown, servers: [<ServerDescription ('mongo', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongo:27017: [Errno 8] nodename nor servname provided, or not known (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
# Fix empty labels
for n in G.nodes():
    if not G.nodes[n]["label"]:
        G.nodes[n]["label"] = f"{G.nodes[n]['type']}"

# Assign colors
color_map = {
    "concept": "#4E79A7",
    "resource": "#F28E2B",
    "example": "#E15759",
}

node_colors = [color_map[G.nodes[n]["type"]] for n in G.nodes()]
# Out:
# Loaded:
#  - Nodes: 48
#  - Edges: 27

# %%
G = nx.DiGraph()

missing_type = 0
missing_label = 0

for node in nodes:
    node_id = node.get("id")

    if not node_id:
        continue

    node_type = node.get("type")
    node_label = node.get("title") or node.get("text")

    if node_type is None:
        missing_type += 1
        continue  # skip nodes with no type

    if node_label is None:
        missing_label += 1
        node_label = ""  # fallback

    G.add_node(
        node_id,
        type=node_type,
        label=node_label
    )

# Add edges (keep only if both endpoints exist)
for edge in edges:
    s, t = edge["source"], edge["target"]
    if s in G.nodes and t in G.nodes:
        G.add_edge(s, t, type=edge["type"])

print("Graph built!")
print("Total nodes with type:", G.number_of_nodes())
print("Missing type nodes skipped:", missing_type)
print("Missing label nodes:", missing_label)
print("Edges:", G.number_of_edges())
# Out:
# Graph built!
# Total nodes with type: 48
# Missing type nodes skipped: 0
# Missing label nodes: 16
# Edges: 26

# %%
concept_nodes = [
    n for n, data in G.nodes(data=True)
    if data.get("type") == "concept"
]

print("Concept nodes kept:", len(concept_nodes))

H = G.subgraph(concept_nodes).copy()

print("Subgraph nodes:", H.number_of_nodes())
print("Subgraph edges:", H.number_of_edges())
# Out:
# Concept nodes kept: 19
# Subgraph nodes: 19
# Subgraph edges: 5

# %%
import matplotlib.pyplot as plt
import networkx as nx

plt.figure(figsize=(16, 10))

# Compute "depth" (layer number) based on number of prerequisites
layer = {}
for n in H.nodes:
    layer[n] = len(list(H.predecessors(n)))

# Convert layers into y-levels: deeper concepts → lower on page
pos = {}
for n in H.nodes:
    pos[n] = (layer[n], -layer[n] * 0.5)  # x = layer, y = negative layer to spread vertically

# Draw graph
nx.draw(
    H, pos,
    with_labels=True,
    node_size=1800,
    node_color="#4d8cf5",
    font_size=9,
    font_color="white",
    arrows=True,
    arrowstyle="-|>",
    arrowsize=12
)

plt.title("Knowledge Graph – Concepts Only (Layered DAG Layout)")
plt.show()

# %%
bad_edges = []
for e in edges:
    if e["source"] not in G.nodes or e["target"] not in G.nodes:
        bad_edges.append(e)

len(bad_edges), bad_edges[:10]
# Out:
# (1,
#  [{'_id': ObjectId('6934a074962f69216cc624ee'),
#    'id': '3892889d-f07d-4563-ad88-139961add796',
#    'type': 'prereq_of',
#    'source': 'a10572fb-31fc-43ca-b57e-711737a517ab',
#    'target': 'near-transfer checks',
#    'chunk_id': 'cc0b42fd-6a5f-4a8d-9f9d-916bf58bcb9f'}])

# %%
correct_id = "a10572fb-31fc-43ca-b57e-711737a517ab"

fixed_edges = []

for e in edges:
    src = e["source"]
    tgt = e["target"]

    # Fix the incorrect target
    if tgt == "near-transfer checks":
        tgt = correct_id

    # Skip edges referencing non-existent nodes
    if src not in G.nodes or tgt not in G.nodes:
        continue

    fixed_edges.append({"type": e["type"], "source": src, "target": tgt})

print("Original edges:", len(edges))
print("Fixed edges:", len(fixed_edges))
# Out:
# Original edges: 27
# Fixed edges: 27

# %%
G2 = nx.DiGraph()

# Copy all nodes
for n, d in G.nodes(data=True):
    G2.add_node(n, **d)

# Add corrected edges
for e in fixed_edges:
    G2.add_edge(e["source"], e["target"], type=e["type"])

print("Graph G2 ready with:", len(G2.nodes), "nodes and", len(G2.edges), "edges")
# Out:
# Graph G2 ready with: 48 nodes and 27 edges

# %%
concept_edges = [
    e for e in fixed_edges
    if G2.nodes[e["source"]].get("type") == "concept"
    and G2.nodes[e["target"]].get("type") == "concept"
]

print("Concept-concept edges:", len(concept_edges))
concept_edges
# Out:
# Concept-concept edges: 6
# [{'type': 'prereq_of',
#   'source': 'ad7a466d-9d5b-4a4f-8319-7f431d0d8aa4',
#   'target': '2e164628-d549-447d-a3e5-f6d9fda90595'},
#  {'type': 'prereq_of',
#   'source': '75aa2e0d-6a61-41a1-9437-20394bf7ff20',
#   'target': '4a60f614-9e5d-457f-ab70-15317275d663'},
#  {'type': 'prereq_of',
#   'source': 'f8f98a8b-3f1c-4314-85fc-d7019a5c9af9',
#   'target': '7cfe3ad8-d9fc-42ca-bbe1-ba1c95117f9f'},
#  {'type': 'prereq_of',
#   'source': 'a10572fb-31fc-43ca-b57e-711737a517ab',
#   'target': 'a10572fb-31fc-43ca-b57e-711737a517ab'},
#  {'type': 'prereq_of',
#   'source': 'f8d136ec-bc38-4bb6-9e9f-9b5534692856',
#   'target': '91ccf9bf-651d-42e8-8c11-fc7308183470'},
#  {'type': 'prereq_of',
#   'source': 'f8d136ec-bc38-4bb6-9e9f-9b5534692856',
#   'target': '7d7b995f-1e6c-4d48-abeb-bd98a3c4dbea'}]

# %%
from pymongo import MongoClient
import networkx as nx
import matplotlib.pyplot as plt

db = MongoClient("mongodb://localhost:27017").erica
nodes = list(db.entity_nodes.find({}))
edges = list(db.entity_edges.find({}))

print("Nodes:", len(nodes))
print("Edges:", len(edges))
# Out:
# Nodes: 48
# Edges: 27

# %%
G = nx.DiGraph()

for n in nodes:
    nid = n["id"]
    label = n.get("title") or n.get("text") or "UNKNOWN"
    G.add_node(nid, type=n["type"], label=label)

print("Nodes loaded:", len(G.nodes))
# Out:
# Nodes loaded: 48

# %%
# Correcting the wrong target
correct_concept_id = "a10572fb-31fc-43ca-b57e-711737a517ab"

fixed_edges = []

for e in edges:
    src = e["source"]
    tgt = e["target"]

    # Fix the broken edge
    if tgt == "near-transfer checks":
        tgt = correct_concept_id

    # Remove self-loop
    if src == tgt:
        print("Removed self-loop:", src)
        continue

    # Skip if node does not exist
    if src not in G.nodes or tgt not in G.nodes:
        print("Skipping bad edge:", e)
        continue

    fixed_edges.append({"type": e["type"], "source": src, "target": tgt})

print("Original edges:", len(edges))
print("Fixed edges:", len(fixed_edges))
# Out:
# Removed self-loop: a10572fb-31fc-43ca-b57e-711737a517ab
# Original edges: 27
# Fixed edges: 26

# %%
G2 = nx.DiGraph()

for n, d in G.nodes(data=True):
    G2.add_node(n, **d)

for e in fixed_edges:
    G2.add_edge(e["source"], e["target"], type=e["type"])

print("G2 nodes:", len(G2.nodes))
print("G2 edges:", len(G2.edges))
# Out:
# G2 nodes: 48
# G2 edges: 26

# %%
concept_nodes = [n for n, data in G2.nodes(data=True) if data["type"] == "concept"]

concept_edges = [
    e for e in fixed_edges
    if G2.nodes[e["source"]]["type"] == "concept"
    and G2.nodes[e["target"]]["type"] == "concept"
]

print("Concept nodes:", len(concept_nodes))
print("Concept-concept edges:", len(concept_edges))
concept_edges
# Out:
# Concept nodes: 19
# Concept-concept edges: 5
# [{'type': 'prereq_of',
#   'source': 'ad7a466d-9d5b-4a4f-8319-7f431d0d8aa4',
#   'target': '2e164628-d549-447d-a3e5-f6d9fda90595'},
#  {'type': 'prereq_of',
#   'source': '75aa2e0d-6a61-41a1-9437-20394bf7ff20',
#   'target': '4a60f614-9e5d-457f-ab70-15317275d663'},
#  {'type': 'prereq_of',
#   'source': 'f8f98a8b-3f1c-4314-85fc-d7019a5c9af9',
#   'target': '7cfe3ad8-d9fc-42ca-bbe1-ba1c95117f9f'},
#  {'type': 'prereq_of',
#   'source': 'f8d136ec-bc38-4bb6-9e9f-9b5534692856',
#   'target': '91ccf9bf-651d-42e8-8c11-fc7308183470'},
#  {'type': 'prereq_of',
#   'source': 'f8d136ec-bc38-4bb6-9e9f-9b5534692856',
#   'target': '7d7b995f-1e6c-4d48-abeb-bd98a3c4dbea'}]

# %%
H = G2.subgraph(concept_nodes).copy()

print("Subgraph nodes:", len(H.nodes))
print("Subgraph edges:", len(H.edges))
# Out:
# Subgraph nodes: 19
# Subgraph edges: 5

# %%
plt.figure(figsize=(14, 14))
pos = nx.circular_layout(H)

nx.draw_networkx(
    H,
    pos,
    labels={n: H.nodes[n]["label"] for n in H.nodes},
    node_size=1500,
    node_color="#4E79A7",
    font_size=9,
    font_color="white",
    arrows=True,
    arrowstyle="-|>",
    arrowsize=15,
)

plt.title("Knowledge Graph – Concepts Only (Circular Layout)", fontsize=16)
plt.axis("off")
plt.show()

# %%
from networkx.drawing.nx_agraph import graphviz_layout

plt.figure(figsize=(18, 16))
pos = graphviz_layout(H, prog="dot")

nx.draw(
    H,
    pos,
    labels={n: H.nodes[n]["label"] for n in H.nodes},
    with_labels=True,
    node_size=1500,
    node_color="#59A14F",
    font_size=9,
    font_color="white",
    arrows=True,
)

plt.title("Knowledge Graph – Concepts Only (DAG Layout)", fontsize=18)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/networkx/drawing/nx_agraph.py:301, in pygraphviz_layout(G, prog, root, args)
#     300 try:
# --> 301     import pygraphviz
#     302 except ImportError as err:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 4
#       1 from networkx.drawing.nx_agraph import graphviz_layout
#       3 plt.figure(figsize=(18, 16))
# ----> 4 pos = graphviz_layout(H, prog="dot")
#       6 nx.draw(
#       7     H,
#       8     pos,
#    (...)
#      15     arrows=True,
#      16 )
#      18 plt.title("Knowledge Graph – Concepts Only (DAG Layout)", fontsize=18)
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/networkx/drawing/nx_agraph.py:257, in graphviz_layout(G, prog, root, args)
#     226 def graphviz_layout(G, prog="neato", root=None, args=""):
#     227     """Create node positions for G using Graphviz.
#     228
#     229     Parameters
#    (...)
#     255     see https://gitlab.com/graphviz/graphviz/-/issues/1767 for more info.
#     256     """
# --> 257     return pygraphviz_layout(G, prog=prog, root=root, args=args)
#
# File /opt/anaconda3/envs/cogs118a/lib/python3.12/site-packages/networkx/drawing/nx_agraph.py:303, in pygraphviz_layout(G, prog, root, args)
#     301     import pygraphviz
#     302 except ImportError as err:
# --> 303     raise ImportError("requires pygraphviz http://pygraphviz.github.io/") from err
#     304 if root is not None:
#     305     args += f"-Groot={root}"
#
# ImportError: requires pygraphviz http://pygraphviz.github.io/

# %%
color_map = {
    "concept": "#4E79A7",
    "resource": "#F28E2B",
    "example": "#E15759",
}

plt.figure(figsize=(22, 18))
pos = nx.spring_layout(G2, k=0.7, iterations=50)

nx.draw(
    G2,
    pos,
    labels={n: G2.nodes[n]["label"] for n in G2.nodes},
    node_color=[color_map[G2.nodes[n]["type"]] for n in G2.nodes],
    node_size=900,
    font_size=8,
    font_color="white",
    arrows=True,
)

plt.title("Full Knowledge Graph – Concepts, Resources, Examples", fontsize=18)
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

def smart_layout(H):
    # Start with force layout
    pos = nx.spring_layout(H, k=1.1, seed=42)

    # Now adjust Y positions by number of prerequisites (layering)
    indeg = {n: H.in_degree(n) for n in H.nodes()}
    for n, (x, y) in pos.items():
        pos[n] = np.array([x, y - indeg[n] * 0.4])  # push dependent concepts downward

    return pos

plt.figure(figsize=(20, 14))

pos = smart_layout(H)

nx.draw_networkx_nodes(H, pos, node_size=2800, node_color="#4E79A7")
nx.draw_networkx_labels(H, pos, font_size=11, font_color="white")

nx.draw_networkx_edges(
    H,
    pos,
    arrows=True,
    arrowstyle="-|>",
    arrowsize=20,
    edge_color="black",
    width=1.3,
)

plt.title("Knowledge Graph – Concepts Only (Smart Layered Layout)", fontsize=20)
plt.axis("off")
plt.show()
